# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/home/dhinesh/machinelearning/regularized-logesticregression/data/heart.csv')
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# 2        2   0     2       1
# 3        2   0     2       1
# 4        2   0     2       1
# ..     ...  ..   ...     ...
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0
#
# [303 rows x 14 columns]

# %%
x = df.iloc[:,0:13].values
y = df.iloc[:,-1:].values

# %%
pl = sns.countplot("age",hue="target",data=df)
plt.rcParams["figure.figsize"] = (15, 13)
plt.rcParams["xtick.labelsize"] = 10
plt.show()

# %%
def sigmoid(z):
    
    return 1/(1+np.exp(-z))

# %%
def costfunction(theta,X,y):
    l = len(y)
    # here np.dot is a matrix multiplication gives dot product of matrix X and theta
    pred = sigmoid(np.dot(X,theta))
    # the pred is hθ(x)
    error = (-y * np.log(pred)) - ((1-y)*np.log(1-pred))
    
    cost = 1/l * sum(error)
    
    gradient = 1/l * np.dot(X.transpose(),(pred - y))

    return cost[0],gradient

# %% [markdown]
# # FEATURE NORMALIZATION
# * In order to get better accuracy and prediction use feature normalizaton

# %%
def featurenorm(X):
    mean = np.mean(X,axis=0)
    std = np.std(X,axis=0)
    
    X_norm = (X - mean) / std
    
    return X_norm

# %% [markdown]
# # GRADIENT DESCENT
# * Try to get global minima by changing learning rate and number of iterations
# * Repeat {
#      θj:= θj − α/m ∑ (hθ(x(i))−y(i)) xj(i)
#      }

# %%
def gradientdescent(x,y,theta,alpha,iteration):
    m = len(y)
    cost_history = []
    iter_arr = []
    
    for i in range(iteration):
        cost,grad = costfunction(theta,X,y)
        theta = theta - (alpha * grad)
        cost_history.append(cost)
        iter_arr.append(i)
        
    return theta, cost_history, iter_arr

# %%
#Reshaping and get normalized features
u,v = x.shape[0], x.shape[1]
X = np.append(np.ones((u,1)),x,axis=1)
init_theta = np.zeros((v+1,1))
x_norm = featurenorm(X)
y_norm = featurenorm(y)
# Out:
# /home/dhinesh/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: RuntimeWarning: invalid value encountered in true_divide
#   """

# %%
alpha = 0.00001
iteration = 500
th, j_theta, iter_array = gradientdescent(x_norm,y_norm,init_theta,alpha,iteration)
j_theta
# Out:
# [0.6931471805599467,
#  0.46637961304444264,
#  0.33881149320633347,
#  0.2612478371374209,
#  0.21015066082274092,
#  0.17420001197121177,
#  0.14756371926999842,
#  0.12700665883464585,
#  0.11061380542935083,
#  0.09718795358736795,
#  0.08594579465353576,
#  0.07635490202858194,
#  0.06804152404318586,
#  0.06073598031064863,
#  0.054239018669418514,
#  0.04840036045495922,
#  0.04310460046716167,
#  0.03826169183759229,
#  0.03380037264280986,
#  0.02966352897097721,
#  0.025804862231940253,
#  0.022186453181266736,
#  0.018776954042119064,
#  0.015550228062285135,
#  0.012484312747411712,
#  0.009560620559245689,
#  0.0067633160938233685,
#  0.004078825985496792,
#  0.0014954497332412397,
#  -0.0009969519484520591,
#  -0.003407208661280725,
#  -0.005743044823623483,
#  -0.008011247073441393,
#  -0.010217802183073008,
#  -0.012368011364740245,
#  -0.0144665855449136,
#  -0.016517725199760008,
#  -0.018525187590193684,
#  -0.02049234365458539,
#  -0.022422226366728727,
#  -0.02431757201481163,
#  -0.026180855580387914,
#  -0.02801432117730616,
#  -0.029820008336392055,
#  -0.031599774781964664,
